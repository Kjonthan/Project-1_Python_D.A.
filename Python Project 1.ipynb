# %%
# Import library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# Import data set
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)

# %%
df.head()
# Out:
#                                School Name School Level         Regents Exam  \
# School DBN
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8  Common Core Algebra
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8   Living Environment
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8   Living Environment
# 01M140              P.S. 140 Nathan Straus          K-8  Common Core Algebra
# 01M140              P.S. 140 Nathan Straus          K-8  Common Core Algebra
#
#             Year  Total Tested Mean Score Number Scoring Below 65  \
# School DBN
# 01M034      2017             4          s                       s
# 01M034      2015            16       77.9                       1
# 01M034      2016             9         74                       1
# 01M140      2016             3          s                       s
# 01M140      2017             2          s                       s
#
#            Percent Scoring Below 65 Number Scoring 65 or Above  \
# School DBN
# ...

# %%
# Chose the High School I went to
new_df=df.loc[df['School Name']=='John Adams High School']

# %%
new_df
# Out:
#                        School Name School Level                 Regents Exam  \
# School DBN
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school          Common Core Algebra
# 27Q480      John Adams High School  High school          Common Core Algebra
# ...                            ...          ...                          ...
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
#
# ...

# %%
new_df.plot()
# Out:
# <AxesSubplot:xlabel='School DBN'>

# %%
# This visualization is too messy
new_df.plot(kind='scatter',x='Total Tested',y='Mean Score')
# Out:
# <AxesSubplot:xlabel='Total Tested', ylabel='Mean Score'>

# %%
drop_cols=['Number Scoring Below 65','Percent Scoring Below 65','Number Scoring 65 or Above', 'Percent Scoring 65 or Above','Number Scoring 80 or Above','Percent Scoring 80 or Above','Number Scoring CR']

# %%
new_df
# Out:
#                        School Name School Level                 Regents Exam  \
# School DBN
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school          Common Core Algebra
# 27Q480      John Adams High School  High school          Common Core Algebra
# ...                            ...          ...                          ...
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
#
# ...

# %%
print(new_df)
# Out:
#                        School Name School Level                 Regents Exam  \
# School DBN
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school          Common Core Algebra
# 27Q480      John Adams High School  High school          Common Core Algebra
# ...                            ...          ...                          ...
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
#
# ...

# %%
df2=new_df.rename(columns={'Regents Exam':'Exam'})

# %%
df2
# Out:
#                        School Name School Level                         Exam  \
# School DBN
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school          Common Core Algebra
# 27Q480      John Adams High School  High school          Common Core Algebra
# ...                            ...          ...                          ...
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
#
# ...

# %%
df2[df2.Exam!='Algebra2/Trigonometry']
# Out:
#                        School Name School Level                         Exam  \
# School DBN
# 27Q480      John Adams High School  High school          Common Core Algebra
# 27Q480      John Adams High School  High school          Common Core Algebra
# 27Q480      John Adams High School  High school          Common Core Algebra
# 27Q480      John Adams High School  High school         Common Core Algebra2
# 27Q480      John Adams High School  High school         Common Core Algebra2
# ...                            ...          ...                          ...
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
#
# ...

# %%
df2[df2.Exam!='Common Core Algebra2']
# Out:
#                        School Name School Level                         Exam  \
# School DBN
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school        Algebra2/Trigonometry
# 27Q480      John Adams High School  High school          Common Core Algebra
# 27Q480      John Adams High School  High school          Common Core Algebra
# ...                            ...          ...                          ...
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
#
# ...

# %%
df2['Exam']==True
# Out:
# School DBN
# 27Q480    False
# 27Q480    False
# 27Q480    False
# 27Q480    False
# 27Q480    False
#           ...
# 27Q480    False
# 27Q480    False
# 27Q480    False
# 27Q480    False
# 27Q480    False
# Name: Exam, Length: 484, dtype: bool

# %%
df3=df2[df2['Exam']=='U.S. History and Government']

# %%
df3
# Out:
#                        School Name School Level                         Exam  \
# School DBN
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# 27Q480      John Adams High School  High school  U.S. History and Government
# ...

# %%
df3.plot()
# Out:
# <AxesSubplot:xlabel='School DBN'>

# %%
df3.plot(xlabel='Mean Score',x='Mean Score')
# Out:
# <AxesSubplot:xlabel='Mean Score'>

# %%
df3.plot(kind='scatter',x='Total Tested',y='Mean Score')
# Out:
# <AxesSubplot:xlabel='Total Tested', ylabel='Mean Score'>

# %%
print (df)
print (df3)
# Out:
#                                School Name School Level  \
# School DBN
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8
# 01M140              P.S. 140 Nathan Straus          K-8
# 01M140              P.S. 140 Nathan Straus          K-8
# ...                                    ...          ...
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
# 84X717                Icahn Charter School          K-8
#
#                            Regents Exam  Year  Total Tested Mean Score  \
# School DBN
# 01M034              Common Core Algebra  2017             4          s
# 01M034               Living Environment  2015            16       77.9
# ...

# %%
df5=df[df['Regents Exam']=='U.S. History and Government']

# %%
df5
# Out:
#                                     School Name     School Level  \
# School DBN
# 01M292               Orchard Collegiate Academy      High school
# 01M292               Orchard Collegiate Academy      High school
# 01M292               Orchard Collegiate Academy      High school
# 01M448      University Neighborhood High School      High school
# 01M448      University Neighborhood High School      High school
# ...                                         ...              ...
# 84X704              KIPP Academy Charter School  K-12 all grades
# 84X704              KIPP Academy Charter School  K-12 all grades
# 84X704              KIPP Academy Charter School  K-12 all grades
# 84X706            Harriet Tubman Charter School              K-8
# 84X717                     Icahn Charter School              K-8
#
#                            Regents Exam  Year  Total Tested Mean Score  \
# School DBN
# 01M292      U.S. History and Government  2015            45       71.7
# ...

# %%
df5.plot(xlabel='Mean Score',x='Mean Score')
# Out:
# <AxesSubplot:xlabel='Mean Score'>

# %%
#Try merging data set and subset
df3.plot(xlabel='Mean Score',x='Mean Score')
df5.plot(xlabel='Mean Score',x='Mean Score')
# Out:
# <AxesSubplot:xlabel='Mean Score'>

# %%
df3['Year'].astype(str).astype(int)
# Out:
# School DBN
# 27Q480    2015
# 27Q480    2016
# 27Q480    2017
# 27Q480    2015
# 27Q480    2015
# 27Q480    2016
# 27Q480    2016
# 27Q480    2017
# 27Q480    2017
# 27Q480    2015
# 27Q480    2015
# 27Q480    2015
# 27Q480    2016
# 27Q480    2016
# 27Q480    2016
# 27Q480    2017
# 27Q480    2017
# 27Q480    2017
# 27Q480    2015
# 27Q480    2015
# 27Q480    2016
# 27Q480    2016
# 27Q480    2017
# 27Q480    2017
# 27Q480    2015
# 27Q480    2015
# 27Q480    2015
# 27Q480    2015
# 27Q480    2015
# 27Q480    2016
# 27Q480    2016
# 27Q480    2016
# 27Q480    2016
# 27Q480    2016
# 27Q480    2017
# 27Q480    2017
# 27Q480    2017
# 27Q480    2017
# 27Q480    2017
# Name: Year, dtype: int64

# %%
df6=df5.groupby('Mean Score').mean()

# %%
df6
# Out:
#                   Year  Total Tested
# Mean Score
# 33.7        2016.00000      6.000000
# 34.1        2015.00000      8.000000
# 34.2        2016.00000     27.000000
# 36.6        2016.00000     25.000000
# 37.3        2016.00000      6.000000
# ...                ...           ...
# 98.3        2017.00000     88.000000
# 98.4        2016.50000     40.500000
# 98.5        2017.00000     13.500000
# 98.7        2017.00000     15.000000
# s           2016.01921      9.400775
#
# [588 rows x 2 columns]

# %%
df3.plot(xlabel='Mean Score',x='Mean Score')
df6.plot()
# Out:
# <AxesSubplot:xlabel='Mean Score'>

# %%
df7=df3.groupby('Mean Score').mean()

# %%
df7
# Out:
#                    Year  Total Tested
# Mean Score
# 56.9        2016.000000     94.000000
# 57.8        2015.000000    107.000000
# 60.3        2015.000000    156.000000
# 61.2        2017.000000    100.000000
# 64.1        2017.000000    134.000000
# 65.3        2016.000000    150.000000
# 65.8        2016.000000    230.000000
# 68.7        2016.333333    189.333333
# 68.8        2016.000000    359.000000
# 69          2015.000000    313.000000
# 69.1        2015.500000    160.000000
# 69.4        2016.500000    349.500000
# 69.5        2016.500000     80.000000
# 69.8        2015.500000    259.000000
# 70          2016.000000    309.000000
# 70.2        2015.000000    785.000000
# 70.4        2017.000000    636.000000
# 70.7        2015.500000    392.500000
# 71.2        2016.500000    223.500000
# 71.4        2016.000000    574.000000
# 71.8        2015.000000    257.500000
# 72.1        2017.000000    388.500000
# 72.2        2015.000000    678.000000
# ...

# %%
df6.plot(title=('US History Regents Exam - John Adams'))
df7.plot(title=('US History Regents Exam - NYC'))
# Out:
# <AxesSubplot:title={'center':'US History Regents Exam - NYC'}, xlabel='Mean Score'>
